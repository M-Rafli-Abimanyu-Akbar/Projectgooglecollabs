# %% [markdown]
# <a href="https://colab.research.google.com/github/Raflianjay/Projectgooglecollabs/blob/main/GoogleCollabsnuurang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/My Drive
# Out:
# /content/drive/My Drive

# %%
#import libaries
from keras.models import Sequential
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.optimizers import Adam
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from PIL import Image
from imutils import paths
import numpy as np
import os

# %%
#load image
imagepaths = paths.list_images("3scene")
data = []
labels = []

# %%
#resize image
for imagepath in imagepaths:
  image = Image.open(imagepath)
  image = np.array(image.resize((64, 64))) / 255.0
  data.append(image)
  #extract label
  label = imagepath.split(os.path.sep)[-2]
  labels.append(label)

# %%
#convert label from string to binary
lb = LabelBinarizer()
labels =  lb.fit_transform(labels)

# %%
#Split Train and Test data
(x_train, x_test, y_train, y_test) = train_test_split(np.array(data), np.array(labels), test_size = 0.25, shuffle = True)
print(x_train.shape)
print(x_test.shape)
# Out:
# (711, 64, 64, 3)
# (237, 64, 64, 3)

# %%
#Build Model
model = Sequential();
#Flatten Layer
model.add(Flatten(input_shape=(64*64*3,)));
#Hidden Layer#1
model.add(Dense(units=100,
                  activation='relu',
                  kernel_initializer='uniform',));

#Hidden Layer#2
model.add(Dense(units=16,
                  activation='relu',
                  kernel_initializer='uniform'));
#Hidden Layer#2                
model.add(Dense(units=16,
                  activation='relu',
                  kernel_initializer='uniform'));

#Exit Layer
model.add(Dense(units=3,
                  activation='softmax',
                  kernel_initializer='uniform'));

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          (None, 12288)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 100)               1228900
# _________________________________________________________________
# dense_13 (Dense)             (None, 16)                1616
# _________________________________________________________________
# dense_14 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_15 (Dense)             (None, 3)                 51
# =================================================================
# Total params: 1,230,839
# Trainable params: 1,230,839
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Train Model
opt = Adam(lr=3e-4)
model.compile(loss="categorical_crossentropy", optimizer=opt,
	metrics=["accuracy"])
H = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_3_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_3_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# 15/23 [==================>...........] - ETA: 0s - loss: 1.0970 - accuracy: 0.3167WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_3_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# 23/23 [==============================] - 0s 10ms/step - loss: 1.0943 - accuracy: 0.3544 - val_loss: 1.0858 - val_accuracy: 0.3544
# Epoch 2/50
# 23/23 [==============================] - 0s 4ms/step - loss: 1.0691 - accuracy: 0.3896 - val_loss: 1.0485 - val_accuracy: 0.3671
# Epoch 3/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1.0192 - accuracy: 0.4346 - val_loss: 0.9939 - val_accuracy: 0.4684
# Epoch 4/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.9586 - accuracy: 0.5457 - val_loss: 0.9272 - val_accuracy: 0.5232
# Epoch 5/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.8932 - accuracy: 0.5809 - val_loss: 0.8855 - val_accuracy: 0.5232
# Epoch 6/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.8653 - accuracy: 0.5837 - val_loss: 0.8602 - val_accuracy: 0.5570
# Epoch 7/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.8338 - accuracy: 0.5949 - val_loss: 0.8685 - val_accuracy: 0.5485
# Epoch 8/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.8350 - accuracy: 0.5879 - val_loss: 0.8428 - val_accuracy: 0.5570
# Epoch 9/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.8083 - accuracy: 0.6090 - val_loss: 0.8533 - val_accuracy: 0.5443
# Epoch 10/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.8023 - accuracy: 0.6118 - val_loss: 0.8307 - val_accuracy: 0.5570
# Epoch 11/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7833 - accuracy: 0.6174 - val_loss: 0.8370 - val_accuracy: 0.5527
# Epoch 12/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7704 - accuracy: 0.6287 - val_loss: 0.8107 - val_accuracy: 0.5612
# Epoch 13/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7571 - accuracy: 0.6203 - val_loss: 0.8098 - val_accuracy: 0.5570
# Epoch 14/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7352 - accuracy: 0.6329 - val_loss: 0.8045 - val_accuracy: 0.5654
# Epoch 15/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7189 - accuracy: 0.6498 - val_loss: 0.7842 - val_accuracy: 0.5612
# Epoch 16/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.7040 - accuracy: 0.6385 - val_loss: 0.7919 - val_accuracy: 0.6329
# Epoch 17/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6938 - accuracy: 0.7271 - val_loss: 0.7829 - val_accuracy: 0.5781
# Epoch 18/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6825 - accuracy: 0.6681 - val_loss: 0.8332 - val_accuracy: 0.6582
# Epoch 19/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6596 - accuracy: 0.7412 - val_loss: 0.8133 - val_accuracy: 0.6160
# Epoch 20/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6517 - accuracy: 0.7018 - val_loss: 0.7438 - val_accuracy: 0.6751
# Epoch 21/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6795 - accuracy: 0.7046 - val_loss: 0.7292 - val_accuracy: 0.6329
# Epoch 22/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6040 - accuracy: 0.7834 - val_loss: 0.7270 - val_accuracy: 0.7215
# Epoch 23/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5944 - accuracy: 0.7778 - val_loss: 0.7168 - val_accuracy: 0.6751
# Epoch 24/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5679 - accuracy: 0.7778 - val_loss: 0.7018 - val_accuracy: 0.7384
# Epoch 25/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5499 - accuracy: 0.8059 - val_loss: 0.7115 - val_accuracy: 0.6582
# Epoch 26/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5469 - accuracy: 0.7806 - val_loss: 0.6907 - val_accuracy: 0.7426
# Epoch 27/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5122 - accuracy: 0.8256 - val_loss: 0.6932 - val_accuracy: 0.7553
# Epoch 28/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5139 - accuracy: 0.8228 - val_loss: 0.7220 - val_accuracy: 0.7046
# Epoch 29/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4899 - accuracy: 0.8312 - val_loss: 0.6899 - val_accuracy: 0.7257
# Epoch 30/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4800 - accuracy: 0.8172 - val_loss: 0.6672 - val_accuracy: 0.7595
# Epoch 31/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4916 - accuracy: 0.8242 - val_loss: 0.6651 - val_accuracy: 0.7637
# Epoch 32/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4576 - accuracy: 0.8383 - val_loss: 0.6569 - val_accuracy: 0.7553
# Epoch 33/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4403 - accuracy: 0.8551 - val_loss: 0.6492 - val_accuracy: 0.7679
# Epoch 34/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4307 - accuracy: 0.8523 - val_loss: 0.6576 - val_accuracy: 0.7511
# Epoch 35/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4289 - accuracy: 0.8495 - val_loss: 0.6477 - val_accuracy: 0.7722
# Epoch 36/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4021 - accuracy: 0.8636 - val_loss: 0.6483 - val_accuracy: 0.7764
# Epoch 37/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3948 - accuracy: 0.8720 - val_loss: 0.6493 - val_accuracy: 0.7679
# Epoch 38/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4003 - accuracy: 0.8579 - val_loss: 0.6755 - val_accuracy: 0.7553
# Epoch 39/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3948 - accuracy: 0.8706 - val_loss: 0.6404 - val_accuracy: 0.7806
# Epoch 40/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3725 - accuracy: 0.8776 - val_loss: 0.6307 - val_accuracy: 0.7637
# Epoch 41/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3712 - accuracy: 0.8790 - val_loss: 0.6397 - val_accuracy: 0.7426
# Epoch 42/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3614 - accuracy: 0.8776 - val_loss: 0.6576 - val_accuracy: 0.7722
# Epoch 43/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3619 - accuracy: 0.8692 - val_loss: 0.6690 - val_accuracy: 0.7722
# Epoch 44/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3670 - accuracy: 0.8790 - val_loss: 0.6635 - val_accuracy: 0.7637
# Epoch 45/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3263 - accuracy: 0.8973 - val_loss: 0.6317 - val_accuracy: 0.7595
# Epoch 46/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3302 - accuracy: 0.9030 - val_loss: 0.6596 - val_accuracy: 0.7426
# Epoch 47/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3375 - accuracy: 0.8889 - val_loss: 0.6797 - val_accuracy: 0.7848
# Epoch 48/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3231 - accuracy: 0.8945 - val_loss: 0.6912 - val_accuracy: 0.7722
# Epoch 49/50
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3269 - accuracy: 0.8889 - val_loss: 0.6634 - val_accuracy: 0.7384
# Epoch 50/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.8987 - val_loss: 0.6340 - val_accuracy: 0.7848

# %%
import matplotlib.pyplot as plt

print(H.history.keys())
# summarize history for accuracy
plt.plot(H.history['accuracy'])
plt.plot(H.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
predictions = model.predict(x_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
	predictions.argmax(axis=1), target_names=lb.classes_))
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_3_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
#               precision    recall  f1-score   support
#
#        coast       0.75      0.83      0.79        84
#       forest       0.82      0.80      0.81        82
#      highway       0.78      0.70      0.74        71
#
#     accuracy                           0.78       237
#    macro avg       0.79      0.78      0.78       237
# weighted avg       0.79      0.78      0.78       237

# %%
model.save('imageclassificationmodel')
# Out:
# INFO:tensorflow:Assets written to: imageclassificationmodel/assets

# %%
import cv2
import matplotlib.pyplot as plt
image1='test.jpg'

# %%
img_array = cv2.imread(image1)
plt.imshow(img_array)
plt.show()

# %%
image_testing = Image.open('test.jpg')
image_testing = np.array(image_testing.resize((64, 64))) / 255.0
image_testing.shape
# Out:
# (64, 64, 3)

# %%
image_testing = np.expand_dims(image_testing, axis=0)
print(image_testing.shape)
# Out:
# (1, 64, 64, 3)

# %%
output = model.predict(image_testing, 1)
print(output)
print(lb.classes_[output.argmax(axis=1)])
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_3_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (1, 64, 64, 3).
# [[0.11602457 0.81220263 0.07177283]]
# ['forest']
